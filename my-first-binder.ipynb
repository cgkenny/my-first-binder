# %%
# !pip install bs4 pandas html5lib
# Out:
# ...
#      |████████████████████████████████| 9.9 MB 4.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 112 kB 46.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 115 kB 77.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.3 MB 47.8 MB/s eta 0:00:01
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=ddaf34c64bedd2091fc56b2cb2f7e9b7bbad15b73e4c98a5436257f30effec99
#   Stored in directory: /home/jovyan/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built bs4
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# alembic                       1.5.5
# anyio                         2.1.0
# argon2-cffi                   20.1.0
# async-generator               1.10
# attrs                         20.3.0
# Babel                         2.9.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.1
# beautifulsoup4                4.9.3
# bleach                        3.3.0
# blinker                       1.4
# brotlipy                      0.7.0
# bs4                           0.0.1
# certifi                       2020.12.5
# certipy                       0.1.3
# cffi                          1.14.5
# chardet                       4.0.0
# cryptography                  3.4.4
# decorator                     4.4.2
# defusedxml                    0.6.0
# entrypoints                   0.3
# html5lib                      1.1
# idna                          2.10
# ...
